# %%
#Import necessary Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM, Dropout, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
import os
os.chdir("C://Hello/csv_file")

# %%
# load datasets 

df = pd.read_csv("IMDBmoviedataset.csv")
df.head()
# Out:
#      title.id  title.isAdult  title.canRateTitle.isRatable  \
# 0  tt28259207          False                          True
# 1  tt27440937          False                          True
# 2  tt23864864          False                          True
# 3  tt11651796          False                          True
# 4  tt14479746          False                          True
#
#   title.originalTitleText.text title.primaryImage.id  \
# 0                         Kill           rm671641857
# 1                       Weapon          rm3727717121
# 2                        Joram          rm4185347073
# 3                     AK vs AK           rm279368193
# 4                         Thar           rm402464513
#
#                          title.primaryImage.imageUrl  \
# 0  https://m.media-amazon.com/images/M/MV5BZjI1Zj...
# 1  https://m.media-amazon.com/images/M/MV5BMzIxMD...
# 2  https://m.media-amazon.com/images/M/MV5BOWE4M2...
# 3  https://m.media-amazon.com/images/M/MV5BNDJkOT...
# ...

# %%
# Data exploration 
# Check for NULL Values
print(df.isnull().sum())
# Out:
# title.id                                                 0
# title.isAdult                                            0
# title.canRateTitle.isRatable                             0
# title.originalTitleText.text                             0
# title.primaryImage.id                                    0
# title.primaryImage.imageUrl                              0
# title.primaryImage.imageWidth                            0
# title.primaryImage.imageHeight                           0
# title.ratingsSummary.aggregateRating                     0
# title.ratingsSummary.topRanking                        169
# title.ratingsSummary.voteCount                           0
# title.releaseYear.year                                   0
# title.releaseYear.endYear                              169
# title.titleEpisode                                     169
# title.titleText.text                                     0
# title.titleType.id                                       0
# ...

# %%
# Data preprocessing
# Text cleaning function
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
def remove_stopwords(text):
    stop_words = set(stopwards.words('english'))
    words = text.split()
    return ' '.join([word for word in words if word not in stop_words])

def normalize_text(text):
    text = text.lower()
    text = re.sub(r'https?://\S+|www\.\S+', '',text)#REmove URL
    text = re.sub(r"[^a-zA-Z\s]", ' ', text ) # Remove punctuation and non-alpha
    return text 

def clean_text(text):
    text = normalize_text(text)
    text = remove_stopwords(text)
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shiva\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
df['cleaned_review'] = df['review'].apply(clean_text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'review'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['cleaned_review'] = df['review'].apply(clean_text)
#
# ...
